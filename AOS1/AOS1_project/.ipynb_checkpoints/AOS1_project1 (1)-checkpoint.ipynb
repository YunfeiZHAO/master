# %%
import importlib
from  AOS1_project1 import *
#importlib.reload(AOS1_project1)

# %%
ls
# Out:
# AOS1_project1.ipynb  data/          spam_acc.pdf      synth_time.pdf
# AOS1_project1.py     Pima_acc.pdf   spam_time.pdf     Untitled.ipynb
# bcw_acc.pdf          Pima_time.pdf  synth_acc.pdf
# bcw_time.pdf         __pycache__/   synth_result.pdf

# %%
synth = pd.read_csv("data/synth.csv")

# %%
bcw = pd.read_csv("data/bcw.csv")

# %%
pima = pd.read_csv("data/Pima.csv")

# %%
spam = pd.read_csv("data/spambase.csv")

# %%
len(synth)
# Out:
# 1000

# %%
synth.mean()
# Out:
# X1   -0.500576
# X2    1.073006
# z     1.508000
# dtype: float64

# %%
get_pi_hat(synth, 1)
# Out:
# 0.492

# %%
sns.heatmap(synth.drop(columns=["z"]).corr())

# %%
len(bcw)
# Out:
# 683

# %%
bcw.mean()
# Out:
# X1    4.442167
# X2    3.150805
# X3    3.215227
# X4    2.830161
# X5    3.234261
# X6    3.216691
# X7    3.445095
# X8    2.869693
# X9    1.603221
# z     1.349927
# dtype: float64

# %%
get_pi_hat(bcw, 1)
# Out:
# 0.6500732064421669

# %%
sns.heatmap(bcw.drop(columns=["z"]).corr())

# %%
len(pima)
# Out:
# 532

# %%
pima.mean()
# Out:
# npreg      3.516917
# glu      121.030075
# bp        71.505639
# skin      29.182331
# bmi       32.890226
# ped        0.502966
# age       31.614662
# z          1.332707
# dtype: float64

# %%
get_pi_hat(pima, 1)
# Out:
# 0.6672932330827067

# %%
sns.heatmap(pima.drop(columns=["z"]).corr())

# %%
len(spam)
# Out:
# 4601

# %%
spam.mean()
# Out:
# X1       0.104553
# X2       0.213015
# X3       0.280656
# X4       0.065425
# X5       0.312223
# X6       0.095901
# X7       0.114208
# X8       0.105295
# X9       0.090067
# X10      0.239413
# X11      0.059824
# X12      0.541702
# X13      0.093930
# X14      0.058626
# X15      0.049205
# X16      0.248848
# X17      0.142586
# X18      0.184745
# X19      1.662100
# X20      0.085577
# X21      0.809761
# X22      0.121202
# X23      0.101645
# X24      0.094269
# X25      0.549504
# X26      0.265384
# X27      0.767305
# X28      0.124845
# X29      0.098915
# X30      0.102852
# X31      0.064753
# X32      0.047048
# X33      0.097229
# X34      0.047835
# X35      0.105412
# X36      0.097477
# X37      0.136953
# X38      0.013201
# X39      0.078629
# X40      0.064834
# X41      0.043667
# X42      0.132339
# X43      0.046099
# X44      0.079196
# X45      0.301224
# X46      0.179824
# X47      0.005444
# X48      0.031869
# X49      0.038575
# X50      0.139030
# X51      0.016976
# X52      0.269071
# X53      0.075811
# X54      0.044238
# X55      5.191515
# X56     52.172789
# X57    283.289285
# z        1.605955
# dtype: float64

# %%
get_pi_hat(spam, 1)
# Out:
# 0.39404477287546186

# %%
sns.heatmap(spam.drop(columns=["z"]).corr())

# %%
data = pd.read_csv("data/spambase.csv")
y = data.z.to_numpy()
X = data.drop(columns=["z"]).to_numpy()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=30)
gda = GDA()
gda.fit(X_train, y_train)
y_pred = gda.predict(X_test)
print(f'accuracy:\n {accuracy_score(y_test, y_pred)}')
print(f'confusion_matrix:\n {confusion_matrix(y_test, y_pred)}')
# Out:
# accuracy:
#  0.8124547429398986
# confusion_matrix:
#  [[473  45]
#  [214 649]]

# %%
y_pred
# Out:
# array([1, 2, 1, ..., 2, 1, 1])

#  [ 2.88777774e-03 -3.94406764e-02  2.78555853e-01 ... -7.46824619e-02
#   -4.26611209e-01 -5.25139507e+00]
#  ...
#  [-4.54455875e-04 -7.64656747e-02 -7.46824619e-02 ...  3.52489618e+01
#    2.26103179e+02  3.19357111e+02]
#  [-8.59661757e-02 -2.07593499e+00 -4.26611209e-01 ...  2.26103179e+02
#    1.92333575e+03  5.54306275e+03]
#  [-1.63575520e+00 -2.93470183e+01 -5.25139507e+00 ...  3.19357111e+02
#    5.54306275e+03  1.35756469e+05]]

# %%
is_pos_def(cov1)
# Out:
# True

# %%
check_symmetric(cov1)
# Out:
# True

# %%
def run_RGDA_prediction(data_path):
    data = pd.read_csv(data_path)
    y = data.z.to_numpy()
    X = data.drop(columns=["z"]).to_numpy()
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=30)
    d = X.shape[1]
    mu = 0
    kappa = 1
    Lambda = np.eye(d)
    rgba = RGDA(mu, kappa, Lambda)
    rgba.fit(X_train, y_train)
    y_pred = rgba.predict(X_test)
    print(f'accuracy:\n {accuracy_score(y_test, y_pred)}')
    print(f'confusion_matrix:\n {confusion_matrix(y_test, y_pred)}')

# %%
run_RGDA_prediction("data/synth.csv")
# Out:
# accuracy:
#  0.9566666666666667
# confusion_matrix:
#  [[131   6]
#  [  7 156]]

# %%
data = pd.read_csv("data/synth.csv")
y = data.z.to_numpy()
X = data.drop(columns=["z"]).to_numpy()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=30)
d = X.shape[1]
mu = 0
kappa = 1
Lambda = np.eye(d)
rgba = RGDA(mu, kappa, Lambda)
rgba.fit(X_train, y_train)

# %%
rgba.show_params()
# Out:
# mu_hat_1: [-1.93993135 -0.88176998]
# mu_hat_2: [0.95535055 2.92535707]
# sigma_hat_1:
# [[1.92767322 0.8910512 ]
#  [0.8910512  2.79236171]]
# sigma_hat_2:
# [[ 4.22148467 -2.21435403]
#  [-2.21435403  3.04048789]]

# %% [markdown]
# # Result Analysis

# %% [markdown]
# ## synth.csv

# %%
y = synth.z.to_numpy()
X = synth.drop(columns=["z"]).to_numpy()

# %% [markdown]
# ### GDA: Gaussian Discriminant Analysis

# %%
r = cross_validate(GDA(), X, y, 
               scoring = 'accuracy', return_train_score=True)
print(f"mean_fit_time: {mean(r['fit_time'])}\nmean_score_time: {mean(r['score_time'])}\nmean_train_score: {mean(r['test_score'])}\nmean_test_score: {mean(r['train_score'])}")
r
# Out:
# mean_fit_time: 0.0003685474395751953
# mean_score_time: 0.0006006717681884766
# mean_train_score: 0.9410000000000001
# mean_test_score: 0.96425
# {'fit_time': array([0.00062156, 0.00043535, 0.00026941, 0.0002656 , 0.00025082]),
#  'score_time': array([0.00075674, 0.00062704, 0.0005672 , 0.00052691, 0.00052547]),
#  'test_score': array([0.935, 0.93 , 0.965, 0.955, 0.92 ]),
#  'train_score': array([0.96125, 0.965  , 0.96375, 0.96375, 0.9675 ])}

# %% [markdown]
# ### QLR: Quadratic Logistic Regression model

# %%
r = cross_validate(RQLR('none', solver='newton-cg'), X, y, 
               scoring = 'accuracy', return_train_score=True)
print(f"mean_fit_time: {mean(r['fit_time'])}\nmean_score_time: {mean(r['score_time'])}\nmean_train_score: {mean(r['test_score'])}\nmean_test_score: {mean(r['train_score'])}")
r
# Out:
# mean_fit_time: 0.019524288177490235
# mean_score_time: 0.00038604736328125
# mean_train_score: 0.962
# mean_test_score: 0.96675
# {'fit_time': array([0.05667877, 0.01276112, 0.0094831 , 0.00991917, 0.00877929]),
#  'score_time': array([0.00043583, 0.0004096 , 0.00036788, 0.00036287, 0.00035405]),
#  'test_score': array([0.985, 0.975, 0.97 , 0.94 , 0.94 ]),
#  'train_score': array([0.96125, 0.965  , 0.965  , 0.97125, 0.97125])}

# %% [markdown]
# ### RGDA: regularized Gaussian Discriminant Analysis

# %%
mu = 0
kappa = 1
Lambda = np.eye(d)
r = cross_validate(RGDA(mu, kappa, Lambda), X, y, 
               scoring = 'accuracy', return_train_score=True)
print(f"mean_fit_time: {mean(r['fit_time'])}\nmean_score_time: {mean(r['score_time'])}\nmean_train_score: {mean(r['test_score'])}\nmean_test_score: {mean(r['train_score'])}")
r
# Out:
# mean_fit_time: 0.00043625831604003905
# mean_score_time: 0.0006096839904785156
# mean_train_score: 0.9410000000000001
# mean_test_score: 0.96425
# {'fit_time': array([0.00063324, 0.00044823, 0.00035596, 0.00034428, 0.00039959]),
#  'score_time': array([0.00072908, 0.00058675, 0.00055885, 0.00053954, 0.00063419]),
#  'test_score': array([0.935, 0.925, 0.965, 0.96 , 0.92 ]),
#  'train_score': array([0.96125, 0.965  , 0.9625 , 0.96375, 0.96875])}

# %% [markdown]
# ### RQLR: Regularized Quadratic Logistic Regression model

# %%
r = cross_validate(RQLR('elasticnet', 'saga', l1_ratio=0.5), X, y, 
               scoring = 'accuracy', return_train_score=True)
print(f"mean_fit_time: {mean(r['fit_time'])}\nmean_score_time: {mean(r['score_time'])}\nmean_train_score: {mean(r['test_score'])}\nmean_test_score: {mean(r['train_score'])}")
r
# Out:
# mean_fit_time: 0.06479783058166504
# mean_score_time: 0.00042662620544433596
# mean_train_score: 0.9630000000000001
# mean_test_score: 0.9652499999999999
# {'fit_time': array([0.05143619, 0.05467033, 0.08033776, 0.05305099, 0.08449388]),
#  'score_time': array([0.00051403, 0.00048494, 0.00044084, 0.00034022, 0.0003531 ]),
#  'test_score': array([0.98 , 0.975, 0.975, 0.94 , 0.945]),
#  'train_score': array([0.95875, 0.965  , 0.9625 , 0.97125, 0.96875])}

# %% [markdown]
# # model comparison on different datasets

# %%
df_synth = models_comparison("data/synth.csv", "synth")

# %%
df_synth.groupby('model').mean()
# Out:
#        fit_time  score_time  test_score  train_score
# model
# GDA    0.000318    0.000660       0.941      0.96425
# QLR    0.010414    0.000451       0.962      0.96675
# RGDA   0.000303    0.000459       0.941      0.96425
# RQLR   0.010040    0.000395       0.964      0.96475

# %%
df_pima = models_comparison("data/Pima.csv", "Pima")
# Out:
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:477: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:477: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:477: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:477: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:477: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:477: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:477: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:477: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:477: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:477: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:477: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:437: LineSearchWarning: Rounding errors prevent the line search from converging
#   warn(msg, LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.conda/envs/UBS/lib/python3.6/site-packages/sklearn/utils/optimize.py:204: UserWarning: Line Search failed
#   warnings.warn('Line Search failed')
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:477: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:437: LineSearchWarning: Rounding errors prevent the line search from converging
#   warn(msg, LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.conda/envs/UBS/lib/python3.6/site-packages/sklearn/utils/optimize.py:204: UserWarning: Line Search failed
#   warnings.warn('Line Search failed')
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:477: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:477: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:477: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.conda/envs/UBS/lib/python3.6/site-packages/sklearn/utils/optimize.py:204: UserWarning: Line Search failed
#   warnings.warn('Line Search failed')
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:477: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:477: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:477: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:477: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:477: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:477: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:477: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:477: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:437: LineSearchWarning: Rounding errors prevent the line search from converging
#   warn(msg, LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.conda/envs/UBS/lib/python3.6/site-packages/sklearn/utils/optimize.py:204: UserWarning: Line Search failed
#   warnings.warn('Line Search failed')
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:437: LineSearchWarning: Rounding errors prevent the line search from converging
#   warn(msg, LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.conda/envs/UBS/lib/python3.6/site-packages/sklearn/utils/optimize.py:204: UserWarning: Line Search failed
#   warnings.warn('Line Search failed')
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:477: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:477: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/yunfei/.conda/envs/UBS/lib/python3.6/site-packages/sklearn/utils/optimize.py:204: UserWarning: Line Search failed
#   warnings.warn('Line Search failed')

# %%
df_pima.groupby('model').mean()
# Out:
#        fit_time  score_time  test_score  train_score
# model
# GDA    0.000286    0.000710    0.687533     0.800731
# QLR    2.262908    0.000563    0.748193     0.808278
# RGDA   0.000361    0.000657    0.683795     0.796967
# RQLR   2.663986    0.000563    0.755687     0.805457

# %%
df_bcw = models_comparison("data/bcw.csv", "bcw")

# %%
df_bcw.groupby('model').mean()
# Out:
#        fit_time  score_time  test_score  train_score
# model
# GDA    0.000325    0.000787    0.942980     0.956079
# QLR    0.231656    0.000616    0.928306     1.000000
# RGDA   0.004539    0.000746    0.941531     0.955348
# RQLR   0.101783    0.000580    0.942991     0.992683

# %%
df_spambase = models_comparison("data/spambase.csv", "spam")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-fdce489cd65d> in <module>()
# ----> 1 df_spambase = models_comparison("data/spambase.csv", "spam")
#
# ~/Desktop/AOS1_project/AOS1_project1.py in models_comparison(data_path, name)
#     132     # QLR
#     133     r = cross_validate(RQLR('none', solver='newton-cg'), X, y,
# --> 134                        scoring='accuracy', return_train_score=True)
#     135     r["model"] = "QLR"
#     136     df = df.append(pd.DataFrame(data=r), ignore_index=True)
#
# ~/.conda/envs/UBS/lib/python3.6/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/.conda/envs/UBS/lib/python3.6/site-packages/sklearn/model_selection/_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     246             return_times=True, return_estimator=return_estimator,
#     247             error_score=error_score)
# --> 248         for train, test in cv.split(X, y, groups))
#     249
#     250     zipped_scores = list(zip(*scores))
#
# ~/.conda/envs/UBS/lib/python3.6/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1027             # remaining jobs.
#    1028             self._iterating = False
# -> 1029             if self.dispatch_one_batch(iterator):
#    1030                 self._iterating = self._original_iterator is not None
#    1031
#
# ~/.conda/envs/UBS/lib/python3.6/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     845                 return False
#     846             else:
# --> 847                 self._dispatch(tasks)
#     848                 return True
#     849
#
# ~/.conda/envs/UBS/lib/python3.6/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     763         with self._lock:
#     764             job_idx = len(self._jobs)
# --> 765             job = self._backend.apply_async(batch, callback=cb)
#     766             # A job can complete so quickly than its callback is
#     767             # called before we get here, causing self._jobs to
#
# ~/.conda/envs/UBS/lib/python3.6/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~/.conda/envs/UBS/lib/python3.6/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~/.conda/envs/UBS/lib/python3.6/site-packages/joblib/parallel.py in __call__(self)
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     252             return [func(*args, **kwargs)
# --> 253                     for func, args, kwargs in self.items]
#     254
#     255     def __reduce__(self):
#
# ~/.conda/envs/UBS/lib/python3.6/site-packages/joblib/parallel.py in <listcomp>(.0)
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     252             return [func(*args, **kwargs)
# --> 253                     for func, args, kwargs in self.items]
#     254
#     255     def __reduce__(self):
#
# ~/.conda/envs/UBS/lib/python3.6/site-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     529             estimator.fit(X_train, **fit_params)
#     530         else:
# --> 531             estimator.fit(X_train, y_train, **fit_params)
#     532
#     533     except Exception as e:
#
# ~/.conda/envs/UBS/lib/python3.6/site-packages/sklearn/pipeline.py in fit(self, X, y, **fit_params)
#     333             if self._final_estimator != 'passthrough':
#     334                 fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 335                 self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     336
#     337         return self
#
# ~/.conda/envs/UBS/lib/python3.6/site-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1415                       penalty=penalty, max_squared_sum=max_squared_sum,
#    1416                       sample_weight=sample_weight)
# -> 1417             for class_, warm_start_coef_ in zip(classes_, warm_start_coef))
#    1418
#    1419         fold_coefs_, _, n_iter_ = zip(*fold_coefs_)
#
# ~/.conda/envs/UBS/lib/python3.6/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1027             # remaining jobs.
#    1028             self._iterating = False
# -> 1029             if self.dispatch_one_batch(iterator):
#    1030                 self._iterating = self._original_iterator is not None
#    1031
#
# ~/.conda/envs/UBS/lib/python3.6/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     845                 return False
#     846             else:
# --> 847                 self._dispatch(tasks)
#     848                 return True
#     849
#
# ~/.conda/envs/UBS/lib/python3.6/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     763         with self._lock:
#     764             job_idx = len(self._jobs)
# --> 765             job = self._backend.apply_async(batch, callback=cb)
#     766             # A job can complete so quickly than its callback is
#     767             # called before we get here, causing self._jobs to
#
# ~/.conda/envs/UBS/lib/python3.6/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~/.conda/envs/UBS/lib/python3.6/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~/.conda/envs/UBS/lib/python3.6/site-packages/joblib/parallel.py in __call__(self)
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     252             return [func(*args, **kwargs)
# --> 253                     for func, args, kwargs in self.items]
#     254
#     255     def __reduce__(self):
#
# ~/.conda/envs/UBS/lib/python3.6/site-packages/joblib/parallel.py in <listcomp>(.0)
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     252             return [func(*args, **kwargs)
# --> 253                     for func, args, kwargs in self.items]
#     254
#     255     def __reduce__(self):
#
# ~/.conda/envs/UBS/lib/python3.6/site-packages/sklearn/linear_model/_logistic.py in _logistic_regression_path(X, y, pos_class, Cs, fit_intercept, max_iter, tol, verbose, solver, coef, class_weight, dual, penalty, intercept_scaling, multi_class, random_state, check_input, max_squared_sum, sample_weight, l1_ratio)
#     767             args = (X, target, 1. / C, sample_weight)
#     768             w0, n_iter_i = _newton_cg(hess, func, grad, w0, args=args,
# --> 769                                       maxiter=max_iter, tol=tol)
#     770         elif solver == 'liblinear':
#     771             coef_, intercept_, n_iter_i, = _fit_liblinear(
#
# ~/.conda/envs/UBS/lib/python3.6/site-packages/sklearn/utils/optimize.py in _newton_cg(grad_hess, func, grad, x0, args, tol, maxiter, maxinner, line_search, warn)
#     192         # Inner loop: solve the Newton update by conjugate gradient, to
#     193         # avoid inverting the Hessian
# --> 194         xsupi = _cg(fhess_p, fgrad, maxiter=maxinner, tol=termcond)
#     195
#     196         alphak = 1.0
#
# ~/.conda/envs/UBS/lib/python3.6/site-packages/sklearn/utils/optimize.py in _cg(fhess_p, fgrad, maxiter, tol)
#      89             break
#      90
# ---> 91         Ap = fhess_p(psupi)
#      92         # check curvature
#      93         curv = np.dot(psupi, Ap)
#
# ~/.conda/envs/UBS/lib/python3.6/site-packages/sklearn/linear_model/_logistic.py in Hs(s)
#     233     def Hs(s):
#     234         ret = np.empty_like(s)
# --> 235         ret[:n_features] = X.T.dot(dX.dot(s[:n_features]))
#     236         ret[:n_features] += alpha * s[:n_features]
#     237
#
# KeyboardInterrupt:

# %%
df_spambase.groupby('model').mean()
# Out:
#          fit_time  score_time  test_score  train_score
# model
# GDA      0.006265    0.021892    0.828271     0.837207
# QLR    542.425780    0.008111    0.921759     0.992611
# RGDA     0.020957    0.009703    0.831312     0.837859
# RQLR   194.492422    0.005932    0.393827     0.394099

# %% [markdown]
# # Draw decision boundary for synth

# %%
y = synth.z.to_numpy()
X = synth.drop(columns=["z"]).to_numpy()

# %% [markdown]
# ## GDA boundary

# %%
gda = GDA()
gda.fit(X, y)

# %%
plot_gda_boundry(gda, "GDA", synth)
# Out:
# /home/yunfei/.conda/envs/UBS/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## QLR boundry

# %%
qlr = RQLR('none', solver='newton-cg')
qlr.fit(X, y)
sns.scatterplot(x="X1", y="X2", data=synth, hue="z")
add_decision_boundary(qlr)
# Out:
# /home/yunfei/.conda/envs/UBS/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## RGDA boundary

# %%
d = X.shape[1]
mu = 0
kappa = 1
Lambda = np.eye(d)
rgda = RGDA(mu, kappa, Lambda)
rgda.fit(X, y)
plot_gda_boundry(rgda, "RGDA", synth)
# Out:
# /home/yunfei/.conda/envs/UBS/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## RQLR boundry

# %%
rqlr = RQLR('elasticnet', 'saga', l1_ratio=0.5)
rqlr.fit(X, y)
sns.scatterplot(x="X1", y="X2", data=synth, hue="z")
add_decision_boundary(rqlr)
# Out:
# /home/yunfei/.conda/envs/UBS/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
